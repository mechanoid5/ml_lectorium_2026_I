# %% [markdown]
# __библиотека numpy__

# %% [markdown]
# - Абдрахманов М.И., Мамонов И.А.  Линейная алгебра на Python. - devpractice.ru. 2019.
#
# - Криволапов С.Я., Хрипунова М.Б.    Математика на Python. - КноРус. 2022
#
# - https://github.com/rougier/numpy-100

# %% [markdown]
# ----

# %% [markdown]
# # Импортируйте пакет numpy под именем np

# %% [markdown]
# # Распечатайте версию numpy

# %% [markdown]
# # Создайте вектор из нулей размером 10

# %% [markdown]
# # Как определить объем занимаемой масивом памяти

# %% [markdown]
# # Как получить справку по функции add

# %% [markdown]
# # Создайте нулевой вектор размером 10, но с пятым значением, равным 1

# %% [markdown]
# # Создайте вектор со значениями от 10 до 49

# %% [markdown]
# # "Переверните" вектор (первый элемент станет последним)

# %% [markdown]
# # Создайте матрицу 3х3 со значениями от 0 до 8

# %% [markdown]
# # Найдите индексы ненулевых элементов из [1,2,0,0,4,0]

# %% [markdown]
# # Создайте единичную матрицу 3х3

# %% [markdown]
# # Создайте массив 3х3х3 со случайными значениями

# %% [markdown]
# # Создайте массив 10х10 со случайными значениями и найдите минимальное и максимальное значения

# %% [markdown]
# # Создайте случайный вектор размером 30 и найдите среднее значение

# %% [markdown]
# # Создайте двумерный массив с 1 на границе и 0 внутри

# %% [markdown]
# # Как добавить границу (заполненную нулями) вокруг существующего массива?

# %% [markdown]
# # Создайте матрицу размером 5х5 со значениями 1,2,3,4 чуть ниже главной диагонали

# %% [markdown]
# # Извлеките целую часть из случайного массива чисел

# %% [markdown]
# # Создайте матрицу размером 5х5 со значениями в строках от 0 до 4

# %% [markdown]
# # Создайте случайный вектор размером 10 и отсортируйте его

# %% [markdown]
# # Сгенерируйте два случайных массива A и B, проверьте их на равенство

# %% [markdown]
# # Сгенерируйте случайную матрицу размером 10х2, представляющую декартовы координаты, преобразуйте их в полярные координаты

# %% [markdown]
# # Для двух случайных массивов X и Y постройте матрицу C
# $C_{ij} = \frac{1}{x_i - y_j}$

# %% [markdown]
# # Сгенерируйте две случайные матрицы A и B, перемножьте их

# %% [markdown]
# # Сгенерируйте вектор a и матрицу B, перемножте их
