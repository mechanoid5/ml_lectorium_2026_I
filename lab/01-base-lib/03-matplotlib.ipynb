# %% [markdown]
# __библиотека matplotlib__

# %% [markdown]
# - Абдрахманов М.И., Мамонов И.А.  Линейная алгебра на Python. - devpractice.ru. 2019.
#
# - Криволапов С.Я., Хрипунова М.Б.    Математика на Python. - КноРус. 2022
#
# - https://github.com/rougier/numpy-100

# %% [markdown]
# # Импортируйте пакет numpy

# %% [markdown]
# # Импортируйте пакет matplotlib

# %% [markdown]
# # Сгенерируйте случайную матрицу из 1000 точек размерности 2

# %% [markdown]
# # Нарисуйте сгенерированные в п.3 точки на плоскости

# %% [markdown]
# # постройте гистограммы первого и второго столбца матрицы из п.3, расположите их на двух картинках размещённых в один ряд (subplots)

# %% [markdown]
# # нарисуйте график функции $\frac{sin(x^2)}{x}$

# %% [markdown]
# # Импортируйте пакет seaborn

# %% [markdown]
# # сгенерируйте случайную матрицу 10 на 10, нарисуйте по ней тепловую карту (heatmap)
