# %% [markdown]
# __библиотека numpy__

# %% [markdown]
# __Упражнения__
#
# https://github.com/rougier/numpy-100

# %% [markdown]
# - Абдрахманов М.И., Мамонов И.А.  Линейная алгебра на Python. - devpractice.ru. 2019.
#
# - Криволапов С.Я., Хрипунова М.Б.    Математика на Python. - КноРус. 2022

# %%
import numpy as np

# %%
np.__name__ # имя пакета
# Out:
# 'numpy'

# %%
np.__version__ # версия пакета
# Out:
# '2.3.4'

# %%
# help(np.random) # справка по модулям пакета

# %%
np.set_printoptions(precision=2) # вывод на печать до 2 знака
