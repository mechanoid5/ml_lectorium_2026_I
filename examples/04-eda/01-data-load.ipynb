# %% [markdown]
# **загрузка данных**
#
# Евгений Борисов esborisov@sevsu.ru

# %%
import numpy as np
from numpy import random as rng
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # генерация синтетических данных

# %% [markdown]
# Пошаговое руководство по созданию синтетических данных в Python
# https://habr.com/ru/companies/netologyru/articles/841952/
#
# Игра в имитацию: используем Python для генерации синтетических данных для ML и не только
# https://habr.com/ru/articles/888830/

# %%
from sklearn.datasets import make_blobs

x_blobs, target_blobs = make_blobs(n_samples=1024, centers=4, cluster_std=rng.uniform(size=4)+.7 )
display( x_blobs.shape )
# Out:
# (1024, 2)

# %%
from sklearn.datasets import make_moons
x_moons, target_moons = make_moons(n_samples=1024, noise=.09)
display( x_moons.shape )
# Out:
# (1024, 2)

# %%
from sklearn.datasets import  make_circles
x_circ, target_circ = make_circles(n_samples=1024, noise=.09)
display( x_circ.shape )
# Out:
# (1024, 2)

# %%
from sklearn.datasets import make_regression

x_reg, y_reg = make_regression( n_samples=1024, n_features=1, noise=25., )
display( x_reg.shape, x_reg.shape )
# Out:
# (1024, 1)
# (1024, 1)

# %%
fig,ax = plt.subplots(2,2,figsize=(9,7))

ax[0,0].scatter(x_moons[:,0],x_moons[:,1],c=target_moons,s=1.2,alpha=0.5,cmap='rainbow')
ax[0,0].set_title('make_moons')
ax[0,0].grid()

ax[0,1].scatter(x_blobs[:,0],x_blobs[:,1],c=target_blobs,s=1.2,alpha=0.5,cmap='rainbow')
ax[0,1].set_title('make_blobs')
ax[0,1].grid()

ax[1,0].scatter(x_circ[:,0],x_circ[:,1],c=target_circ,s=1.2,alpha=0.5,cmap='rainbow')
ax[1,0].set_title('make_circles')
ax[1,0].grid()

ax[1,1].scatter(x_reg, y_reg,s=1.2,alpha=0.5)
ax[1,1].set_title('make_regression')
ax[1,1].grid()

plt.tight_layout()

# %%
from sklearn.datasets import make_classification
x_class, target_class = make_classification(n_samples=1024, n_features=27, n_classes=2)
display(x_class.shape)


from sklearn.decomposition import PCA

x_2_class = PCA(n_components=2).fit_transform(x_class)

fig = plt.figure(figsize=(4,3))
plt.scatter(x_2_class[:,0],x_2_class[:,1],c=target_class,s=1.2,alpha=0.5,cmap='rainbow')
plt.title('make_classification')
plt.grid()
plt.show()
# Out:
# (1024, 27)

# %% [markdown]
# ----

# %%
# pip install faker

# %%
# синтез  не числовых данных
from faker import Faker

n_samples = 10

fake = Faker(['ru_RU'])

df = pd.DataFrame({
     'Name': [ fake.name() for _ in range(n_samples)], 
     'Address': [ fake.address() for _ in range(n_samples)], 
     'Email': [ fake.email() for _ in range(n_samples)], 
     'Phone Number': [ fake.phone_number() for _ in range(n_samples)],
 })
 
display(df)
# Out:
#                             Name  \
# 0  Феврония Вениаминовна Блохина
# 1     Соболева Пелагея Мироновна
# 2       Ананий Борисович Данилов
# 3        Тихонова Ия Григорьевна
# 4         Марфа Сергеевна Фомина
# 5             Агафон Фокич Щукин
# 6     Никитин Владлен Харламович
# 7         Изот Данилович Тетерин
# 8  Кириллов Климент Харлампьевич
# 9   Сысоева Прасковья Робертовна
#
#                                              Address  \
# 0   д. Тутаев, алл. Л.Толстого, д. 3/4 к. 24, 746716
# 1  к. Зарайск, бул. 40 лет Октября, д. 6/6 к. 1/5...
# 2          к. Сочи, ш. Московское, д. 8 к. 5, 980623
# 3         г. Сыктывкар, бул. Рябиновый, д. 5, 087313
# 4          п. Бодайбо, ш. Сахалинское, д. 61, 535977
# 5  с. Астрахань, пер. Таежный, д. 2/5 стр. 71, 34...
# 6  к. Салехард, бул. Свердлова, д. 3 стр. 41, 567584
# 7  п. Усть-Кулом, бул. Орловский, д. 6 к. 6/9, 82...
# 8  п. Усть-Кулом, ул. Орджоникидзе, д. 24 к. 7/7,...
# 9       к. Хатанга, алл. Придорожная, д. 4/6, 569649
#
#                            Email       Phone Number
# 0       jakovlevfirs@example.com        89142456511
# 1        ippolit2006@example.com  +7 (888) 510-6472
# 2         angelina43@example.net  +7 (282) 279-9829
# 3      kazakovaverki@example.org  8 (375) 003-26-04
# 4  kallistratsamolov@example.org  +7 (014) 789-2157
# 5       ustinovmilen@example.net  8 (927) 034-03-48
# 6          iermakova@example.org  8 (413) 049-11-21
# 7         juvenali97@example.com        85426296020
# 8          vitali_25@example.org  8 (527) 352-05-05
# 9   kalashnikovaalla@example.org    +7 024 592 3872

# %% [markdown]
# ----

# %%
## use torch
# pip install sdv

# %%
# генерация синтетических датасетов с помощью статистических моделей
    
# from sdv.single_table import GaussianCopulaSynthesizer
# from sdv.datasets.demo import download_demo

# # загружаем датасет с данными по взрослым
# df, metadata = download_demo(dataset_name='adult', modality='single_table')
# display( df.sample(3) )

# # # Use GaussianCopulaSynthesizer to train on the data 
# # # (используем моделирование гауссовыми копулами для обучения модели на основе данных)
# # model = GaussianCopulaSynthesizer(metadata)
# # model.fit(df)

# # # Generate Synthetic data (генерируем синтетические данные)
# # df_ = model.sample(2)
# # display(df_)

# # del df,df_,metadata

# %%
# Gretel Synthetics: генерация приватных синтетических данных

# from gretel_synthetics import TextGenerator
# import pandas as pd

# # Шаблон для обучения модели (логи)
# training_data = [
#     "ERROR [2023-11-05 12:30:45] Service 'payment_gateway' timeout (500ms > 300ms threshold)",
#     "WARN [2023-11-05 12:31:10] Database connection pool 80% full",
#     "INFO [2023-11-05 12:31:22] User 2345 initiated USD to EUR transfer"
# ]

# pd.DataFrame(training_data, columns=["log"]).to_csv("logs.csv", index=False)

# # Конфигурация модели с анонимизацией
# config = {
#     "model_type": "LSTM",
#     "epochs": 50,
#     "anonymize": True  # Маскируем цифры и названия сервисов
# }

# # Обучение и генерация
# generator = TextGenerator(config=config)
# generator.train("logs.csv")
# synth_logs = generator.generate(num_records=100)

# print(synth_logs[0])

# %% [markdown]
# # работа с файлами

# %%
# создадим файлы с данными
n_samples = 1024
df = pd.DataFrame({
     'Name': [ fake.name() for _ in range(n_samples)], 
     'Address': [ fake.address() for _ in range(n_samples)], 
     'Email': [ fake.email() for _ in range(n_samples)], 
     'Phone Number': [ fake.phone_number() for _ in range(n_samples)],
 })

df.to_pickle('fake-data.pkl')
df.to_csv('fake-data.csv',sep='\t',index=False)
df.to_json('fake-data.json',orient='records', force_ascii=False)

# %%
pd.read_pickle('fake-data.pkl')
# Out:
#                                   Name  \
# 0        Русакова Прасковья Алексеевна
# 1         Самсонова Варвара Тимофеевна
# 2            Порфирий Яковлевич Зайцев
# 3          Корнилова Евдокия Яковлевна
# 4        Евфросиния Игоревна Степанова
# ...                                ...
# 1019         Романова Ольга Михайловна
# 1020  Беспалова Варвара Константиновна
# 1021        Людмила Борисовна Фомичева
# 1022             Исай Ануфриевич Котов
# 1023           Шарапов Конон Демидович
#
#                                                 Address  \
# 0     клх Нязепетровск, алл. Физкультурная, д. 861, ...
# 1     с. Батайск, наб. Сурикова, д. 599 стр. 6/1, 47...
# 2     п. Змеиногорск, бул. Октябрьский, д. 92 к. 2, ...
# 3     клх Сызрань, ш. Черняховского, д. 94 к. 90, 14...
# 4             п. Туруханск, наб. Дачная, д. 6/5, 994038
# ...                                                 ...
# 1019  к. Волоколамск, ул. Больничная, д. 7 к. 30, 39...
# 1020  п. Славянск-на-Кубани, ш. Безымянное, д. 2/4, ...
# 1021      клх Шамары, пр. 40 лет Победы, д. 137, 439502
# 1022    г. Кетченеры, бул. Коллективный, д. 529, 320190
# 1023          г. Уфа, ул. Весенняя, д. 7 стр. 2, 317539
#
#                              Email       Phone Number
# 0            antonin28@example.com       +70023287141
# 1          marija_2013@example.net       +70390958720
# 2           amvrosi_66@example.com    +7 151 832 7363
# 3           volkovlavr@example.org  +7 (633) 060-6089
# 4       prohorovlukjan@example.com       +72946079204
# ...                            ...                ...
# 1019      averjan_1993@example.net        87504990755
# 1020     milanalekseev@example.net     8 642 342 3980
# 1021       kalininagap@example.net   8 (988) 001-1359
# 1022  jaroslavnekrasov@example.net  8 (779) 890-68-55
# 1023        tnikolaeva@example.org     8 291 353 8341
#
# [1024 rows x 4 columns]

# %%
pd.read_csv('fake-data.csv',sep='\t')
# Out:
#                                   Name  \
# 0        Русакова Прасковья Алексеевна
# 1         Самсонова Варвара Тимофеевна
# 2            Порфирий Яковлевич Зайцев
# 3          Корнилова Евдокия Яковлевна
# 4        Евфросиния Игоревна Степанова
# ...                                ...
# 1019         Романова Ольга Михайловна
# 1020  Беспалова Варвара Константиновна
# 1021        Людмила Борисовна Фомичева
# 1022             Исай Ануфриевич Котов
# 1023           Шарапов Конон Демидович
#
#                                                 Address  \
# 0     клх Нязепетровск, алл. Физкультурная, д. 861, ...
# 1     с. Батайск, наб. Сурикова, д. 599 стр. 6/1, 47...
# 2     п. Змеиногорск, бул. Октябрьский, д. 92 к. 2, ...
# 3     клх Сызрань, ш. Черняховского, д. 94 к. 90, 14...
# 4             п. Туруханск, наб. Дачная, д. 6/5, 994038
# ...                                                 ...
# 1019  к. Волоколамск, ул. Больничная, д. 7 к. 30, 39...
# 1020  п. Славянск-на-Кубани, ш. Безымянное, д. 2/4, ...
# 1021      клх Шамары, пр. 40 лет Победы, д. 137, 439502
# 1022    г. Кетченеры, бул. Коллективный, д. 529, 320190
# 1023          г. Уфа, ул. Весенняя, д. 7 стр. 2, 317539
#
#                              Email       Phone Number
# 0            antonin28@example.com       +70023287141
# 1          marija_2013@example.net       +70390958720
# 2           amvrosi_66@example.com    +7 151 832 7363
# 3           volkovlavr@example.org  +7 (633) 060-6089
# 4       prohorovlukjan@example.com       +72946079204
# ...                            ...                ...
# 1019      averjan_1993@example.net        87504990755
# 1020     milanalekseev@example.net     8 642 342 3980
# 1021       kalininagap@example.net   8 (988) 001-1359
# 1022  jaroslavnekrasov@example.net  8 (779) 890-68-55
# 1023        tnikolaeva@example.org     8 291 353 8341
#
# [1024 rows x 4 columns]

# %%
pd.read_json('fake-data.json')
# Out:
#                                   Name  \
# 0        Русакова Прасковья Алексеевна
# 1         Самсонова Варвара Тимофеевна
# 2            Порфирий Яковлевич Зайцев
# 3          Корнилова Евдокия Яковлевна
# 4        Евфросиния Игоревна Степанова
# ...                                ...
# 1019         Романова Ольга Михайловна
# 1020  Беспалова Варвара Константиновна
# 1021        Людмила Борисовна Фомичева
# 1022             Исай Ануфриевич Котов
# 1023           Шарапов Конон Демидович
#
#                                                 Address  \
# 0     клх Нязепетровск, алл. Физкультурная, д. 861, ...
# 1     с. Батайск, наб. Сурикова, д. 599 стр. 6/1, 47...
# 2     п. Змеиногорск, бул. Октябрьский, д. 92 к. 2, ...
# 3     клх Сызрань, ш. Черняховского, д. 94 к. 90, 14...
# 4             п. Туруханск, наб. Дачная, д. 6/5, 994038
# ...                                                 ...
# 1019  к. Волоколамск, ул. Больничная, д. 7 к. 30, 39...
# 1020  п. Славянск-на-Кубани, ш. Безымянное, д. 2/4, ...
# 1021      клх Шамары, пр. 40 лет Победы, д. 137, 439502
# 1022    г. Кетченеры, бул. Коллективный, д. 529, 320190
# 1023          г. Уфа, ул. Весенняя, д. 7 стр. 2, 317539
#
#                              Email       Phone Number
# 0            antonin28@example.com       +70023287141
# 1          marija_2013@example.net       +70390958720
# 2           amvrosi_66@example.com    +7 151 832 7363
# 3           volkovlavr@example.org  +7 (633) 060-6089
# 4       prohorovlukjan@example.com       +72946079204
# ...                            ...                ...
# 1019      averjan_1993@example.net        87504990755
# 1020     milanalekseev@example.net     8 642 342 3980
# 1021       kalininagap@example.net   8 (988) 001-1359
# 1022  jaroslavnekrasov@example.net  8 (779) 890-68-55
# 1023        tnikolaeva@example.org     8 291 353 8341
#
# [1024 rows x 4 columns]

# %% [markdown]
# ----

# %%
# числовые данные
x = rng.normal(-1.,+1.,(1024,256))
y = rng.normal(-1.,+1.,(1024,128))

x.shape,y.shape
# Out:
# ((1024, 256), (1024, 128))

# %%
np.save('fake-data.npy',x)

# %%
np.load('fake-data.npy')
# Out:
# array([[-1.4991013 ,  0.69571146, -0.96253707, ..., -1.93034179,
#         -0.70723786, -0.62151083],
#        [-2.39016918, -0.31297273, -1.34494228, ...,  0.00907833,
#         -1.52563086, -1.91180058],
#        [-2.54698973,  0.06951587, -2.48494619, ..., -0.51760525,
#          0.23373898, -0.89339961],
#        ...,
#        [-0.31516511, -1.876071  , -1.81740037, ...,  0.72949717,
#         -0.44121141, -0.36279957],
#        [ 0.89955368, -0.99110518, -1.29036074, ...,  0.33391856,
#         -3.07495359, -0.56807849],
#        [ 1.78512259, -0.41606297,  0.19889397, ..., -1.46078781,
#         -1.82170502,  0.22226619]], shape=(1024, 256))

# %%
np.save('fake-data.npy',{'x':x,'y':y})

# %%
np.load('fake-data.npy', allow_pickle=True)
# Out:
# array({'x': array([[-1.4991013 ,  0.69571146, -0.96253707, ..., -1.93034179,
#         -0.70723786, -0.62151083],
#        [-2.39016918, -0.31297273, -1.34494228, ...,  0.00907833,
#         -1.52563086, -1.91180058],
#        [-2.54698973,  0.06951587, -2.48494619, ..., -0.51760525,
#          0.23373898, -0.89339961],
#        ...,
#        [-0.31516511, -1.876071  , -1.81740037, ...,  0.72949717,
#         -0.44121141, -0.36279957],
#        [ 0.89955368, -0.99110518, -1.29036074, ...,  0.33391856,
#         -3.07495359, -0.56807849],
#        [ 1.78512259, -0.41606297,  0.19889397, ..., -1.46078781,
#         -1.82170502,  0.22226619]], shape=(1024, 256)), 'y': array([[-1.96232343, -2.32986726, -0.58802539, ..., -0.38789965,
#         -1.18683834,  0.0160322 ],
#        [ 0.24526612, -0.88715601, -0.74736856, ..., -1.2222223 ,
#         -1.49533795, -1.41696396],
#        [-0.46397786, -1.06980288,  0.22300563, ..., -0.74164981,
#         -3.14519183,  0.09494948],
#        ...,
#        [ 0.25061034, -0.73512148, -2.57210889, ...,  0.33234432,
#          0.43549569,  0.27975463],
#        [-1.44223788, -0.60139656, -1.92516105, ..., -2.40558851,
#         -0.12896487, -1.42744309],
#        [-1.05421067, -1.11717715, -1.10891693, ..., -0.47936398,
#         -0.41817343, -0.47405008]], shape=(1024, 128))}, dtype=object)

# %% [markdown]
# ----

# %%
import csv

with open('fake-data_x.csv', mode='wt') as f:
    csv.writer(f).writerows(x.tolist())
  
with open('fake-data_x.csv', mode='rt') as f:
    x_ = np.array([ row for row in csv.reader(f) ])

x_.shape
# Out:
# (1024, 256)

# %% [markdown]
# # загрузка из БД

# %%
import sqlite3

# %%
con = sqlite3.connect('fake-data.sqlite')

# %%
df.to_sql(name='fake_data',con=con)
# Out:
# 1024

# %%
pd.read_sql(sql='SELECT * FROM fake_data',con=con)
# Out:
#       index                              Name  \
# 0         0     Русакова Прасковья Алексеевна
# 1         1      Самсонова Варвара Тимофеевна
# 2         2         Порфирий Яковлевич Зайцев
# 3         3       Корнилова Евдокия Яковлевна
# 4         4     Евфросиния Игоревна Степанова
# ...     ...                               ...
# 1019   1019         Романова Ольга Михайловна
# 1020   1020  Беспалова Варвара Константиновна
# 1021   1021        Людмила Борисовна Фомичева
# 1022   1022             Исай Ануфриевич Котов
# 1023   1023           Шарапов Конон Демидович
#
#                                                 Address  \
# 0     клх Нязепетровск, алл. Физкультурная, д. 861, ...
# 1     с. Батайск, наб. Сурикова, д. 599 стр. 6/1, 47...
# 2     п. Змеиногорск, бул. Октябрьский, д. 92 к. 2, ...
# 3     клх Сызрань, ш. Черняховского, д. 94 к. 90, 14...
# 4             п. Туруханск, наб. Дачная, д. 6/5, 994038
# ...                                                 ...
# 1019  к. Волоколамск, ул. Больничная, д. 7 к. 30, 39...
# 1020  п. Славянск-на-Кубани, ш. Безымянное, д. 2/4, ...
# 1021      клх Шамары, пр. 40 лет Победы, д. 137, 439502
# 1022    г. Кетченеры, бул. Коллективный, д. 529, 320190
# 1023          г. Уфа, ул. Весенняя, д. 7 стр. 2, 317539
#
#                              Email       Phone Number
# 0            antonin28@example.com       +70023287141
# 1          marija_2013@example.net       +70390958720
# 2           amvrosi_66@example.com    +7 151 832 7363
# 3           volkovlavr@example.org  +7 (633) 060-6089
# 4       prohorovlukjan@example.com       +72946079204
# ...                            ...                ...
# 1019      averjan_1993@example.net        87504990755
# 1020     milanalekseev@example.net     8 642 342 3980
# 1021       kalininagap@example.net   8 (988) 001-1359
# 1022  jaroslavnekrasov@example.net  8 (779) 890-68-55
# 1023        tnikolaeva@example.org     8 291 353 8341
#
# [1024 rows x 5 columns]

# %%
pd.read_sql(sql='SELECT * FROM fake_data WHERE Name LIKE "%%Игоревна%%"',con=con)
# Out:
#    index                           Name  \
# 0      4  Евфросиния Игоревна Степанова
# 1     78       Лихачева Таисия Игоревна
# 2    400       Трофимова Раиса Игоревна
# 3    548         Анна Игоревна Никитина
# 4    902        Дмитриева Юлия Игоревна
#
#                                              Address  \
# 0          п. Туруханск, наб. Дачная, д. 6/5, 994038
# 1  д. Киров (Вятка), ул. Минина, д. 1/9 стр. 28, ...
# 2   клх Уфа, бул. Кузнецкий, д. 776 стр. 6/9, 426586
# 3  д. Прохладный, алл. Кольцова, д. 61 к. 38, 636914
# 4  г. Заводоуковск, ул. Большевистская, д. 80 к. ...
#
#                           Email        Phone Number
# 0    prohorovlukjan@example.com        +72946079204
# 1      tihonarhipov@example.org        +74210552029
# 2  loginovaevgenija@example.net         88716857566
# 3   vladimirovelise@example.com  +7 (479) 157-26-19
# 4  kopilovinnokenti@example.net     +7 118 632 9398

# %% [markdown]
# # загрузка данных из репозиториев

# %%
from sklearn import datasets

# %%
# dir(datasets)

# %%
# 'fetch_20newsgroups',
#  'fetch_20newsgroups_vectorized',
#  'fetch_california_housing',
#  'fetch_covtype',
#  'fetch_file',
#  'fetch_kddcup99',
#  'fetch_lfw_pairs',
#  'fetch_lfw_people',
#  'fetch_olivetti_faces',
#  'fetch_openml',
#  'fetch_rcv1',
#  'fetch_species_distributions',
#  'get_data_home',
#  'load_breast_cancer',
#  'load_diabetes',
#  'load_digits',
#  'load_files',
#  'load_iris',
#  'load_linnerud',
#  'load_sample_image',
#  'load_sample_images',
#  'load_svmlight_file',
#  'load_svmlight_files',
#  'load_wine'

# %% [markdown]
# ----

# %%
data = datasets.load_wine(as_frame=True)
data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names'])

# %%
print(data['DESCR'][:256])
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 178
# :Number of Attributes: 13 numeric, predictive attributes and the class
# :Attribute Information:
#     - Alcohol
#     - Malic acid

# %%
data['frame']
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline  target
# 0                            3.92   1065.0       0
# 1                            3.40   1050.0       0
# 2                            3.17   1185.0       0
# 3                            3.45   1480.0       0
# 4                            2.93    735.0       0
# ..                            ...      ...     ...
# 173                          1.74    740.0       2
# 174                          1.56    750.0       2
# 175                          1.56    835.0       2
# 176                          1.62    840.0       2
# 177                          1.60    560.0       2
#
# [178 rows x 14 columns]

# %% [markdown]
# ----

# %%
data = datasets.fetch_olivetti_faces()
data.keys()
# Out:
# dict_keys(['data', 'images', 'target', 'DESCR'])

# %%
print(data['DESCR'][:256])
# Out:
# .. _olivetti_faces_dataset:
#
# The Olivetti faces dataset
# --------------------------
#
# `This dataset contains a set of face images`_ taken between April 1992 and
# April 1994 at AT&T Laboratories Cambridge. The
# :func:`sklearn.datasets.fetch_olivetti_faces` func

# %%
data['images'].shape
# Out:
# (400, 64, 64)

# %%
n_samples = 38
n_cols = 10
n_rows = int(np.ceil(n_samples/n_cols))
# fig = plt.figure(figsize=(2*n_rows,2*n_cols))
fig = plt.figure(figsize=(1*n_cols,1*n_rows))
for n in range(n_samples):
    ax = plt.subplot(n_rows,n_cols,n+1)
    ax.imshow(data['images'][n],cmap='gray')
    ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# https://www.openml.org/

# %%
data = datasets.fetch_openml(data_id=1464)
data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
print(data['DESCR'][:256])
# Out:
# **Author**: Prof. I-Cheng Yeh
# **Source**: [UCI](https://archive.ics.uci.edu/ml/datasets/Blood+Transfusion+Service+Center)
# **Please cite**: Yeh, I-Cheng, Yang, King-Jang, and Ting, Tao-Ming, "Knowledge discovery on RFM model using Bernoulli sequence", E

# %%
data['frame']
# Out:
#      V1  V2     V3  V4 Class
# 0     2  50  12500  98     2
# 1     0  13   3250  28     2
# 2     1  16   4000  35     2
# 3     2  20   5000  45     2
# 4     1  24   6000  77     1
# ..   ..  ..    ...  ..   ...
# 743  23   2    500  38     1
# 744  21   2    500  52     1
# 745  23   3    750  62     1
# 746  39   1    250  39     1
# 747  72   1    250  72     1
#
# [748 rows x 5 columns]

# %% [markdown]
# ----

# %% [markdown]
# https://archive.ics.uci.edu/

# %%
# pip install ucimlrepo

# %%
# %%time 

from ucimlrepo import fetch_ucirepo 
data = fetch_ucirepo(id=186)
# Out:
# CPU times: user 42.2 ms, sys: 6.34 ms, total: 48.6 ms
# Wall time: 12.4 s

# %%
data.keys()
# Out:
# dict_keys(['data', 'metadata', 'variables'])

# %%
data['data']['original']
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  color
# 0         9.4        5    red
# 1         9.8        5    red
# 2         9.8        5    red
# 3         9.8        6    red
# 4         9.4        5    red
# ...       ...      ...    ...
# 6492     11.2        6  white
# 6493      9.6        5  white
# 6494      9.4        6  white
# 6495     12.8        7  white
# 6496     11.8        6  white
#
# [6497 rows x 13 columns]

# %% [markdown]
# ---

# %%
import eurostat

toc_df = eurostat.get_toc_df()
toc_df
# Out:
#                                                   title  \
# 0     Unemployed persons by duration of unemployment...
# 1     Unemployed persons by citizenship - quarterly ...
# 2     Unemployed persons by type of employment sough...
# 3     Unemployed persons by methods used for seeking...
# 4     Unemployed persons by previous occupation - qu...
# ...                                                 ...
# 8224  Postal services falling under the universal se...
# 8225                                    Postal services
# 8226    Number of enterprises providing postal services
# 8227  Access points  (USP under direct or indirect d...
# 8228  Domestic postal traffic, letter mail and parce...
#
#                          code     type       last update of data  \
# 0                   LFSQ_UGAD  dataset  2026-01-07T23:00:00+0100
# 1                   LFSQ_UGAN  dataset  2026-01-07T23:00:00+0100
# 2                 LFSQ_UGATES  dataset  2026-01-07T23:00:00+0100
# 3                  LFSQ_UGMSW  dataset  2023-06-01T23:00:00+0200
# 4                  LFSQ_UGPIS  dataset  2023-06-01T11:00:00+0200
# ...                       ...      ...                       ...
# 8224      POST_CUBE1_X$USO701  dataset      2025-04-15T12:44:56Z
# 8225             POST_CUBE1_X  dataset      2025-04-15T12:43:15Z
# 8226      POST_CUBE1_X$NUM701  dataset      2025-04-15T12:44:56Z
# 8227  POST_CUBE1_X$POST_ACC_1  dataset      2025-04-15T12:44:56Z
# 8228  POST_CUBE1_X$POST_DTR_1  dataset      2025-04-15T12:44:56Z
#
#      last table structure change data start data end
# 0       2026-01-07T23:00:00+0100    1998-Q1  2025-Q3
# 1       2026-01-07T23:00:00+0100    1998-Q1  2025-Q3
# 2       2026-01-07T23:00:00+0100    1998-Q1  2020-Q4
# 3       2023-06-01T23:00:00+0200    1998-Q1  2020-Q4
# 4       2024-01-03T23:00:00+0100    1998-Q1  2020-Q4
# ...                          ...        ...      ...
# 8224        2025-04-15T12:44:56Z       None     None
# 8225        2025-04-15T12:43:15Z       2012     2023
# 8226        2025-04-15T12:44:56Z       None     None
# 8227        2025-04-15T12:44:56Z       None     None
# 8228        2025-04-15T12:44:56Z       None     None
#
# [8229 rows x 7 columns]

# %%
data = eurostat.get_data_df('LFSQ_UGAD')
data
# Out:
#       freq     unit sex     age duration geo\TIME_PERIOD  1998-Q1  1998-Q2  \
# 0        Q  THS_PER   F  Y15-19     M1-2              AT      NaN      NaN
# 1        Q  THS_PER   F  Y15-19     M1-2              BA      NaN      NaN
# 2        Q  THS_PER   F  Y15-19     M1-2              BE      NaN      NaN
# 3        Q  THS_PER   F  Y15-19     M1-2              BG      NaN      NaN
# 4        Q  THS_PER   F  Y15-19     M1-2              CH      NaN      NaN
# ...    ...      ...  ..     ...      ...             ...      ...      ...
# 20184    Q  THS_PER   T  Y55-74    TOTAL              SE      NaN     41.7
# 20185    Q  THS_PER   T  Y55-74    TOTAL              SI      NaN      1.5
# 20186    Q  THS_PER   T  Y55-74    TOTAL              SK      9.3      8.1
# 20187    Q  THS_PER   T  Y55-74    TOTAL              TR      NaN      NaN
# 20188    Q  THS_PER   T  Y55-74    TOTAL              UK      NaN    171.0
#
#        1998-Q3  1998-Q4  ...  2023-Q2  2023-Q3  2023-Q4  2024-Q1  2024-Q2  \
# 0          NaN      NaN  ...      NaN      7.3      4.6      NaN      4.7
# 1          NaN      NaN  ...      NaN      NaN      NaN      NaN      NaN
# 2          NaN      NaN  ...      NaN      7.5      NaN      NaN      NaN
# 3          NaN      NaN  ...      NaN      NaN      NaN      NaN      NaN
# 4          NaN      NaN  ...      2.8      2.6      2.0      1.3      2.4
# ...        ...      ...  ...      ...      ...      ...      ...      ...
# 20184      NaN      NaN  ...     64.6     63.6     66.9     75.1     67.9
# 20185      NaN      NaN  ...      7.5      6.7      7.3      6.3      7.6
# 20186      9.6      9.5  ...     19.3     16.8     16.7     15.8     15.3
# 20187      NaN      NaN  ...    193.6    208.6    209.0    227.0    228.0
# 20188      NaN      NaN  ...      NaN      NaN      NaN      NaN      NaN
#
#        2024-Q3  2024-Q4  2025-Q1  2025-Q2  2025-Q3
# 0          7.6      6.3      4.2      NaN      6.8
# 1          NaN      NaN      NaN      NaN      NaN
# 2          7.3      NaN      NaN      NaN      8.7
# 3          NaN      NaN      NaN      NaN      NaN
# 4          2.4      2.4      1.2      2.0      3.4
# ...        ...      ...      ...      ...      ...
# 20184     74.1     73.7     86.7     76.5     76.8
# 20185      7.6      6.7      5.8      6.0      7.2
# 20186     15.3     17.7     19.2     21.2     20.9
# 20187    210.4    231.3    207.9    221.5    228.7
# 20188      NaN      NaN      NaN      NaN      NaN
#
# [20189 rows x 117 columns]
