# %% [markdown]
# **временные ряды и модели ARIMA**
#
# Евгений Борисов <esborisov@sevsu.ru>

# %% [markdown]
# -----

# %% [markdown]
# Дмитрий Макаров   Временные ряды.
# https://www.dmitrymakarov.ru/intro/time-series-20/
#
# Евгений Рябенко Прогнозирование временных рядов.
# https://www.youtube.com/watch?v=u433nrxdf5k

# %% [markdown]
# -----

# %%
import numpy as np
from numpy import random as rng
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %precision 3
np.set_printoptions(precision=2)
np.set_printoptions(linewidth=110)
# np.get_printoptions()

# %% [markdown]
# # загружаем данные

# %% [markdown]
# AirPassengers.csv
#
# https://drive.google.com/file/d/1yfw6gcgmJXCtxkjC69ekUvsEtAiYTlST/view?usp=share_link
#
# https://huggingface.co/spaces/Anniek/Time_series_forecast/raw/main/AirPassengers.csv

# %%
# читаем данные
url = 'https://huggingface.co/spaces/Anniek/Time_series_forecast/raw/main/AirPassengers.csv'
df = pd.read_csv(url).convert_dtypes()
display(df.info())
display(df.describe().T)
display(df.sample(3))
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    string
#  1   #Passengers  144 non-null    Int64
# dtypes: Int64(1), string(1)
# memory usage: 2.5 KB
# None
#              count        mean         std    min    25%    50%    75%    max
# #Passengers  144.0  280.298611  119.966317  104.0  180.0  265.5  360.5  622.0
#       Month  #Passengers
# 70  1954-11          203
# 25  1951-02          150
# 69  1954-10          229

# %%
df['ts'] = pd.to_datetime(df['Month'])
df = df.set_index('ts')
df = df[['#Passengers']]
display(df.sample(3))
# Out:
#             #Passengers
# ts
# 1955-03-01          267
# 1949-07-01          148
# 1956-08-01          405

# %% [markdown]
# # анализ данных

# %% [markdown]
# __1. визуальная оценка графика ряда__

# %%
fig,ax = plt.subplots(figsize = (9,3))
ax.plot(df['#Passengers'], label = 'данные', color = 'steelblue')
ax.plot(df['#Passengers'].rolling(window=12).mean(), label = 'скользящее среднее (12 месяцев)', color = 'orange')
ax.set_xlabel('Месяцы', )
ax.set_ylabel('Количество пассажиров',)
ax.set_title('Перевозки пассажиров с 1949 по 1960 год', )
ax.legend(title = '', loc = 'upper left', )
ax.grid()

# %% [markdown]
# __оценка автокорреляции__

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(df['#Passengers'])
plt.grid()
plt.show()

# %% [markdown]
# __2. стабилизируем дисперсию (Бокс-Кокс)__

# %%
from scipy.special import boxcox

df['bcx'] = boxcox( df['#Passengers'],0 )

# from scipy.special import inv_boxcox
# df['bcx_inv'] = inv_boxcox(df['bcx'],0)

# %%
fig,ax = plt.subplots(2,1, figsize = (7,5),sharex=True)
ax[0].plot(df['#Passengers'], label = 'данные', color = 'steelblue')
ax[0].legend(title = '', loc = 'upper left', )
ax[0].grid()

ax[1].plot(df['bcx'], label = 'boxcox', color = 'red')
ax[1].legend(title = '', loc = 'upper left', )
ax[1].set_xlabel('Месяцы', )
ax[1].grid()

# %% [markdown]
# # модель

# %%
df.index = pd.DatetimeIndex(df.index.values, freq=df.index.inferred_freq)

# разобьём данные на обучающую и тестовую выборки

# обучающая выборка будет включать данные до декабря 1959 года включительно
train = df[:'1959-12']

# тестовая выборка начнется с января 1960 года (по сути, один год)
test = df['1960-01':]

# %%
fig,ax = plt.subplots(figsize = (9,3))
ax.plot(train['#Passengers'], color = 'blue',label='учебная выборка')
ax.plot(test['#Passengers'], color = 'red',label='тестовая выборка')
ax.set_xlabel('Месяцы', )
ax.set_ylabel('Количество пассажиров',)
ax.set_title('Перевозки пассажиров с 1949 по 1960 год', )
ax.legend(title = '', loc = 'upper left', )
ax.grid()

# %%
# train

# %%
# pip install pmdarima

# %%
# импортируем функцию для автоматического подбора параметров модели ARIMA
from pmdarima import auto_arima

# настроим поиск параметров на обучающей выборке
model = auto_arima(
        train['bcx'], 
        start_p=1, 
        start_q=1,
        max_p=3, 
        max_q=3, 
        m=12, 
        start_P=0,
        seasonal=True,
        d=None, 
        D=1, 
        trace=True, 
        error_action ='ignore', 
        suppress_warnings = True,  
        stepwise = True
    )
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=-447.270, Time=1.27 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=-317.949, Time=0.08 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=-433.027, Time=0.72 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=-383.189, Time=0.56 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=-134.983, Time=0.03 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=-416.167, Time=0.31 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=-439.952, Time=1.52 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=-445.310, Time=4.14 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=-439.765, Time=1.40 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=inf, Time=4.97 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=-442.847, Time=0.77 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=-446.293, Time=0.94 sec
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=-445.575, Time=1.44 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=-327.548, Time=0.27 sec
#  ARIMA(0,0,2)(0,1,1)[12] intercept   : AIC=-416.893, Time=0.96 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=-448.052, Time=1.26 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=-417.188, Time=0.22 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=-445.163, Time=1.40 sec
#  ARIMA(2,0,0)(0,1,2)[12] intercept   : AIC=-446.059, Time=4.05 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=-440.423, Time=1.68 sec
#  ARIMA(2,0,0)(1,1,2)[12] intercept   : AIC=inf, Time=4.29 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=-446.264, Time=1.60 sec
#  ARIMA(3,0,1)(0,1,1)[12] intercept   : AIC=-444.359, Time=1.55 sec
#  ARIMA(2,0,0)(0,1,1)[12]             : AIC=-440.545, Time=0.88 sec
#
# Best model:  ARIMA(2,0,0)(0,1,1)[12] intercept
# Total fit time: 36.420 seconds

# %%
# мы можем посмотреть результат с помощью метода summary()
print(model.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  132
# Model:             SARIMAX(2, 0, 0)x(0, 1, [1], 12)   Log Likelihood                 229.026
# Date:                              Sun, 17 May 2026   AIC                           -448.052
# Time:                                      15:38:16   BIC                           -434.114
# Sample:                                  01-01-1949   HQIC                          -442.392
#                                        - 12-01-1959
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0193      0.009      2.161      0.031       0.002       0.037
# ar.L1          0.5990      0.083      7.250      0.000       0.437       0.761
# ar.L2          0.2423      0.085      2.862      0.004       0.076       0.408
# ma.S.L12      -0.5667      0.105     -5.410      0.000      -0.772      -0.361
# sigma2         0.0012      0.000      8.191      0.000       0.001       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 6.11
# Prob(Q):                              0.99   Prob(JB):                         0.05
# Heteroskedasticity (H):               0.36   Skew:                             0.08
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# # тестируем

# %%
from scipy.special import inv_boxcox

n_periods = len(test) # прогноз в месяцах
predicted =  inv_boxcox( model.predict( n_periods=n_periods),0 )

# %%
fig,ax = plt.subplots(figsize = (9,3))
ax.plot(train['#Passengers'], color = 'blue',label='учебная выборка')
ax.plot(test['#Passengers'], color = 'red',label='тестовая выборка')
ax.plot(predicted, color = 'green',  label='прогноз')

ax.set_xlabel('Месяцы', )
ax.set_ylabel('Количество пассажиров',)
ax.set_title('Перевозки пассажиров с 1949 по 1960 год', )
ax.legend(title = '', loc = 'upper left', )
ax.grid()

# %% [markdown]
# ---

# %%
# построим прогноз на три года вперед
predicted = inv_boxcox( model.predict(n_periods=12*3), 0 )

# %%
fig,ax = plt.subplots(figsize = (9,3))
ax.plot(df['#Passengers'], color = 'blue',label='данные')
ax.plot(predicted, color = 'red',label='прогноз на будущее')
ax.set_xlabel('Месяцы', )
ax.set_ylabel('Количество пассажиров',)
ax.set_title('Перевозки пассажиров с 1949 по 1960 год', )
ax.legend(title = '', loc = 'upper left', )
ax.grid()
